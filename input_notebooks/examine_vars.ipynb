# %%
import json
from emu_renewal.inputs import DATA_PATH, VAR_MAP

# %%
vars = {}
for var in VAR_MAP.values():
    vars[var] = json.load(open(DATA_PATH / f"nextclade/{var}.json", "r"))

# %%
vars
