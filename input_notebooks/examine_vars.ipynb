# %% [markdown]
# Inspect the Nextclade data for a particular country.

# %%
from emu_renewal.inputs import get_all_var_data, get_country_var_data, get_country_vars
from emu_renewal.utils import get_row_proportions

# %%
data = get_country_vars("Malaysia")
get_row_proportions(data).plot.area()
