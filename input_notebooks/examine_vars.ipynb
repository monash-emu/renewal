# %%
from emu_renewal.inputs import get_row_proportions, get_all_var_data, get_country_var_data

# %%
raw_data = get_all_var_data()
country_data = get_country_var_data(raw_data, "Malaysia")
get_row_proportions(country_data).plot.area()
