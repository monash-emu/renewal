# %% [markdown]
# Data downloaded from https://databank.worldbank.org/source/population-estimates-and-projections# on 28th January 2025.

# %%
from emu_renewal.inputs import read_worldbank_pop_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from emu_renewal.inputs import read_worldbank_pop_data
#
# ImportError: cannot import name 'read_worldbank_pop_data' from 'emu_renewal.inputs' (/Users/jamestrauer/dev/renewal/emu_renewal/inputs.py)

# %%
read_worldbank_pop_data()

# %%
import pandas as pd
import numpy as np
from emu_renewal.inputs import DATA_PATH

# %%
def read_worldbank_pop_data():
    return pd.read_csv(
        DATA_PATH / "population/6f450edc-f8ef-4d8c-bb2b-dbb1864d88c8_Data.csv", 
        index_col="Country Code",
        na_values=['..'],
        dtype={"2020 [YR2020]": float},
    )["2020 [YR2020]"].dropna()

# %%
pd.read_csv(DATA_PATH / "population/6f450edc-f8ef-4d8c-bb2b-dbb1864d88c8_Data.csv")

# %%
pop_data
