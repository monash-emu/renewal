# %% [markdown]
# Downloaded from https://ec.europa.eu/eurostat/databrowser/view/demo_r_d2jan/default/table?lang=en on 19/1/2025

# %%
import pandas as pd
from emu_renewal.inputs import DATA_PATH

# %%
all_data = pd.read_csv(DATA_PATH / "population/estat_demo_r_d2jan_filtered_en.csv", index_col="geo")
pop_data = all_data.loc[all_data["TIME_PERIOD"] == 2020, "OBS_VALUE"]

# %%
pop_data
# Out:
# geo
# AL:Albania                            2845955
# AL0:Shqipëria                         2845955
# AL01:Veri                              804689
# AL02:Qender                           1176240
# AL03:Jug                               865026
#                                        ...
# TRB2:Van, Muş, Bitlis, Hakkari        2174672
# TRC:Güneydoğu Anadolu                 8975618
# TRC1:Gaziantep, Adıyaman, Kilis       2838319
# TRC2:Şanlıurfa, Diyarbakır            3829967
# TRC3:Mardin, Batman, Şırnak, Siirt    2307332
# Name: OBS_VALUE, Length: 455, dtype: int64
