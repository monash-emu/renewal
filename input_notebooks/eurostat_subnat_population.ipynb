# %% [markdown]
# NUTS2 region downloaded from https://ec.europa.eu/eurostat/databrowser/view/demo_r_pjangroup/default/table?lang=en&category=reg.reg_dem.reg_dempoar as SDMX-CSV on 21/1/2025
# NUTS3 region downloaded from https://ec.europa.eu/eurostat/databrowser/view/demo_r_pjangrp3/default/table?lang=en&category=reg.reg_dem.reg_dempoar as SDMX-CSV on 21/1/2025

# %%
import pandas as pd
from emu_renewal.inputs import DATA_PATH

# %%
nuts2_raw = pd.read_csv(DATA_PATH / "population/estat_demo_r_pjangroup_filtered_en.csv.gz", index_col="geo", usecols=["geo", "OBS_VALUE", "TIME_PERIOD"])
nuts2_data = nuts2_raw.loc[nuts2_raw["TIME_PERIOD"] == 2020, "OBS_VALUE"]
nuts3_raw = pd.read_csv(DATA_PATH / "population/estat_demo_r_pjangrp3_filtered_en.csv.gz", index_col="geo")
nuts3_data = nuts3_raw.loc[nuts3_raw["TIME_PERIOD"] == 2020, "OBS_VALUE"]
