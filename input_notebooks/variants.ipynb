# %% [markdown]
# The following code was run on 11/12/24 to generate the Nextclade genomics data CSV file.

# %%
import pandas as pd
from emu_renewal.inputs import DATA_PATH, VAR_NAMES

# %%
for var in VAR_NAMES:
    path = DATA_PATH / f"nextclade/{var}.json"
    if path.exists():
        print(f"Already extracted {var}")
     path.exists():
        print(f"Extracting {var}")
        url = f"https://github.com/hodcroftlab/covariants/raw/refs/heads/master/cluster_tables/{var}_data.json"
        json_data = pd.read_json(url)
        json_data.to_json(DATA_PATH / f"nextclade/{var}.json")
# Out:
# Already extracted 21K.Omicron
# Already extracted 21L.Omicron
# Already extracted 22B.Omicron
# Already extracted 20A.EU1
# Already extracted 20A.EU2
# Already extracted 20I.Alpha.V1
# Already extracted 20A.S.126A
# Already extracted 20A.S.210T
# Already extracted 20B.S.732A
# Already extracted 20B.S.796H
# Already extracted 20H.Beta.V2
# Already extracted 20I.Alpha.V1
# Already extracted 20J.Gamma.V3
# Already extracted 21A.Delta.S.K417
# Already extracted 21A.Delta
# Already extracted 21B.Kappa
# Already extracted 21C.Epsilon
# Already extracted 21D.Eta
# Already extracted 21F.Iota
# Already extracted 21G.Lambda
# Already extracted 21H.Mu
# Already extracted 21I.Delta
# Already extracted 21J.Delta
# Already extracted 21K.Omicron
# Already extracted 21L.Omicron
# Already extracted 21L
# Already extracted 21M.Omicron
# Already extracted 22A.Omicron
# Already extracted 22B22E
# Already extracted 22C.Omicron
# Already extracted 22D.Omicron
# Already extracted 22E.Omicron
# Already extracted 22F.Omicron
# Already extracted 23A.Omicron
# Already extracted 23B.Omicron
# Already extracted 23C.Omicron
# Already extracted 23D.Omicron
# Already extracted 23E.Omicron
# Already extracted 23F.Omicron
# Already extracted 23G.Omicron
# Already extracted 23H.Omicron
# Already extracted 23I.Omicron
# Already extracted 24A.Omicron
# Already extracted 24B.Omicron
# Already extracted 24C.Omicron
# Already extracted 24D.Omicron
# Already extracted 24E.Omicron
# Already extracted 24F.Omicron
# Already extracted 24G.Omicron
# Already extracted 24H.Omicron
# Already extracted 24I.Omicron
# Already extracted DanishCluster
# Already extracted Delta.145H
# Already extracted Delta.250I
# Already extracted Delta.299I
# Already extracted Delta.N.412R
# Extracting Delta.N.412R
# Already extracted Delta.ORF1a3059F
# Extracting Delta.ORF1a3059F
# Already extracted EUClusters
# Extracting EUClusters
# Already extracted ORF1a.S3675
# Extracting ORF1a.S3675
# Already extracted Omicron.Similar
# Extracting Omicron.Similar
# Already extracted Omicron
# Extracting Omicron
# Already extracted S.A222
# Extracting S.A222
# Already extracted S.A626S
# Extracting S.A626S
# Already extracted S.D80Y
# Extracting S.D80Y
# Already extracted S.E484
# Extracting S.E484
# Already extracted S.H655
# Extracting S.H655
# Already extracted S.H69-
# Extracting S.H69-
# Already extracted S.K417
# Extracting S.K417
# Already extracted S.L18
# Extracting S.L18
# Already extracted S.N439K
# Extracting S.N439K
# Already extracted S.N501
# Extracting S.N501
# Already extracted S.P681
# Extracting S.P681
# Already extracted S.Q613
# Extracting S.Q613
# Already extracted S.Q677H.Bluebird
# Extracting S.Q677H.Bluebird
# Already extracted S.Q677H.Mockingbird
# Extracting S.Q677H.Mockingbird
# Already extracted S.Q677H.Quail
# Extracting S.Q677H.Quail
# Already extracted S.Q677H.Robin1
# Extracting S.Q677H.Robin1
# Already extracted S.Q677H.Robin2
# Extracting S.Q677H.Robin2
# Already extracted S.Q677H.Yellowhammer
# Extracting S.Q677H.Yellowhammer
# Already extracted S.Q677P.Pelican
# Extracting S.Q677P.Pelican
# Already extracted S.Q677R.Roadrunner
# Extracting S.Q677R.Roadrunner
# Already extracted S.Q677
# Extracting S.Q677
# Already extracted S.S477
# Extracting S.S477
# Already extracted S.S98F
# Extracting S.S98F
# Already extracted S.T572
# Extracting S.T572
# Already extracted S.V1122L
# Extracting S.V1122L
# Already extracted S.Y144-
# Extracting S.Y144-
# Already extracted S.Y145
# Extracting S.Y145
# Already extracted S.Y453F
# Extracting S.Y453F
# Already extracted SwissClusters
# Extracting SwissClusters
# Already extracted USAClusters
# Extracting USAClusters
