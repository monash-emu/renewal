# %% [markdown]
# https://databank.worldbank.org/source/subnational-population#

# %%
import pandas as pd
from emu_renewal.inputs import DATA_PATH

# %%
data = pd.read_csv(DATA_PATH / "population/0f28a001-e681-4c68-ba04-dea799bec726_Data.csv", encoding = "ISO-8859-1", index_col="Country Name")[["Level_attr", "2016 [YR2016]"]].dropna()

# %%
# Available countries
set(data["Level_attr"])
# Out:
# {'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Argentina',
#  'Armenia',
#  'Azerbaijan',
#  'Bangladesh',
#  'Belarus',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Chile',
#  'China',
#  'Colombia',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Czech Republic',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt, Arab Rep.',
#  'El Salvador',
#  'Estonia',
#  'Ethiopia',
#  'Gambia, The',
#  'Georgia',
#  'Ghana',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Honduras',
#  'Hungary',
#  'India',
#  'Indonesia',
#  'Iran, Islamic Rep.',
#  'Iraq',
#  'Jamaica',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Korea, Rep.',
#  'Kyrgyz Republic',
#  'Lao PDR',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Lithuania',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Mexico',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
# ...

# %%
# Select a country
data[data["Level_attr"] == "Afghanistan"]
# Out:
#                           Level_attr  2016 [YR2016]
# Country Name
# Afghanistan, Badakhshan  Afghanistan      1216000.0
# Afghanistan, Badghis     Afghanistan       634000.0
# Afghanistan, Baghlan     Afghanistan      1164000.0
# Afghanistan, Balkh       Afghanistan      1695000.0
# Afghanistan, Bamyan      Afghanistan       572000.0
# Afghanistan, Daykundi    Afghanistan       514000.0
# Afghanistan, Farah       Afghanistan       649000.0
# Afghanistan, Faryab      Afghanistan      1277000.0
# Afghanistan, Ghazni      Afghanistan      1571000.0
# Afghanistan, Ghor        Afghanistan       883000.0
# Afghanistan, Herat       Afghanistan      2417000.0
# Afghanistan, Hilmand     Afghanistan      1182000.0
# Afghanistan, Jawzjan     Afghanistan       691000.0
# Afghanistan, Kabul       Afghanistan      5590000.0
# Afghanistan, Kandahar    Afghanistan      1568000.0
# Afghanistan, Kapisa      Afghanistan       564000.0
# Afghanistan, Khost       Afghanistan       735000.0
# ...
