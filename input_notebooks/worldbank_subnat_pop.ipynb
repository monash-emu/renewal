# %%
import pandas as pd
from emu_renewal.inputs import DATA_PATH

# %%
data = pd.read_csv(DATA_PATH / "population/worldbank_subnational_pop.csv", encoding = "ISO-8859-1", index_col="Country Name")["2016 [YR2016]"].dropna()

# %%
# Available countries
start_idx = 1865
data.index[start_idx: start_idx + 99]
