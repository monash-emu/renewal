# %%
import pandas as pd
from emu_renewal.inputs import DATA_PATH

# %%
data = pd.read_csv(DATA_PATH / "population/worldbank_subnational_pop.csv", encoding = "ISO-8859-1", index_col="Country Name")[["Level_attr", "2016 [YR2016]"]].dropna()

# %%
# Available countries
set(data["Level_attr"])

# %%
# Select a country
data[data["Level_attr"] == "Afghanistan"]
