# %%
import json
from datetime import datetime

from emu_renewal.inputs import DATA_PATH, ANALYSIS_TYPES, DATE_FORMAT, get_standard_priors
from emu_renewal.run import run_single_country

# %%
countries = json.load(open(DATA_PATH / f"config/included.json", "r"))
analysis_time = datetime.now().strftime(DATE_FORMAT)
for country in ["KOR"]:
    for mob_analysis_type in ["no_mob"]:
        run_single_country(country, 7, 50, mob_analysis_type, 100, 50, analysis_time, prog_bar=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/dev/renewal/code/emu_renewal/run.py in ?(country, proc_update_freq, init_duration, mob_analysis_type, n_iters, run_data_delay, analysis_name, most_extreme_prop, death_start_threshold, seed_duration, n_chains, prog_bar, logger)
#     311     except Exception as e:
#     312         msg = f"{mob_analysis_type} mobility not available"
# --> 313         raise MobilityException(msg)
#     314     if mob_provider.mob_end:
#
# ~/dev/renewal/code/emu_renewal/run.py in ?(iso3, mob_type)
#     221     # Get mobility provider object
#     222     exp_prior = {"mob_exp": dist.Uniform(0.0, 2.0)}
# --> 223     n_domains = len(mob.columns)
#     224     if mob_type == "no_mob":
#
# ~/dev/renewal/.pixi/envs/default/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'
#
# During handling of the above exception, another exception occurred:
#
# MobilityException                         Traceback (most recent call last)
# Cell In[2], line 5
#       3 for country in ["KOR"]:
#       4     for mob_analysis_type in ["no_mob"]:
# ----> 5         run_single_country(country, 7, 50, mob_analysis_type, 100, 50, analysis_time, prog_bar=True)
#
# File ~/dev/renewal/code/emu_renewal/run.py:313, in run_single_country(country, proc_update_freq, init_duration, mob_analysis_type, n_iters, run_data_delay, analysis_name, most_extreme_prop, death_start_threshold, seed_duration, n_chains, prog_bar, logger)
#     311 except Exception as e:
#     312     msg = f"{mob_analysis_type} mobility not available"
# --> 313     raise MobilityException(msg)
#     314 if mob_provider.mob_end:
#     315     end_time = min([end_time, mob_provider.mob_end])
#
# MobilityException: no_mob mobility not available
