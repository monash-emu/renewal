# %%
from datetime import datetime
import numpy as np

from emu_renewal.renew import SimpleModel
from emu_renewal.mobility import NoMobilityProvider

# %%
pop = 1e6
run_start = datetime(2020, 1, 1)
end_time = datetime(2020, 12, 31)
var_names = ["wild"]
seed_times = []
mob_provider = NoMobilityProvider()
vacc_effect = False

# %%
model = SimpleModel(
    pop,
    run_start,
    end_time,
    var_names,
    seed_times,
    mob_provider,
    vacc_effect,
)

# %%
model.renewal_func(
    1.0,
    np.array([1.0]),
    1.0,
    1.0,
    0.5,
    0.01,
    5.0,
    1.0,
    20.0,
    2.0,
    0.5,
    np.array([0.0]),
    None,
)
