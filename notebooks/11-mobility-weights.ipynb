# %% [raw]
# ---
# title: "Outputs"
# format:
#   pdf
# execute:
#   echo: false
#   warning: false
# jupyter: python3
# ---

# %%
from matplotlib_inline.backend_inline import set_matplotlib_formats
from matplotlib.pyplot import cm
from os import listdir as ls

from emu_renewal.inputs import OUTPUTS_PATH
from emu_renewal.plotting import plot_mob_weights_by_country

# %%
set_matplotlib_formats("svg")
colours = cm.Dark2.colors

# %%
job_path = OUTPUTS_PATH / "42780561"
countries = ls(job_path)

# %%
plot_mob_weights_by_country(job_path, "google")

# %%
plot_mob_weights_by_country(job_path, "apple")
