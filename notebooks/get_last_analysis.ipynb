# %%
import os
from datetime import datetime

from emu_renewal.inputs import OUTPUTS_PATH

# %%
country = "France"

# %%
country_path = OUTPUTS_PATH / country
for analysis in os.listdir(country_path):
    path = country_path / analysis
    print(path)
    datetime.strptime(os.listdir(path)[-1], "%Y%m%d_%H%M")
# Out:
# C:\Users\jtrauer\dev\renewal\outputs\France\fb_linear
# C:\Users\jtrauer\dev\renewal\outputs\France\fb_square
# C:\Users\jtrauer\dev\renewal\outputs\France\google_nonresi_linear
# C:\Users\jtrauer\dev\renewal\outputs\France\google_nonresi_square
# C:\Users\jtrauer\dev\renewal\outputs\France\no_mob
