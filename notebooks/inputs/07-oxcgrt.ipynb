# %%
import pandas as pd

# %%
url = "https://github.com/OxCGRT/covid-policy-dataset/raw/refs/heads/main/data/OxCGRT_fullwithnotes_national_2020_v1.csv"
dtypes = {
    "V2B_Vaccine age eligibility/availability age floor (general population summary)": str,
    "V2C_Vaccine age eligibility/availability age floor (at risk summary)": str,
    "V4_Notes": str,
}   
data = pd.read_csv(url, index_col="CountryCode", dtype=dtypes)
