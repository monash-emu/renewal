# %% [markdown]
# ## Notes on run 43514097
# - Canada - seropositive proportion very strange, **NO ACTION**
# - France - may need another pooling on seroprevalence, **DONE**
# - Kyrgyzstan - should be excluded, not sure why it ran in last full batch, **NO ACTION**
# - Congo - looks impossible to get good calibration, **NO ACTION**
# - Pakistan - seroprevalence values are consistently decreasing, **DONE**
# - Australia - not in included countries **DONE**
# - Japan - check why the occupancy values are so infrequent **DONE**
# - Bulgaria - same occupancy issue as Japan, poor calibration **DONE**
# - Croatia - nonsense calibration, like Bulgaria before patch **DONE**
# - Paraguay - uptick in EU at end of simulation **DONE**
# - Lebanon - big uptick in EU at end of simulation **DONE**
# - Uganda - nonsense calibration; finishes very late (early 2022) **BROKEN AGAIN**
# - Cabo Verde - moderate quality calibration **NO ACTION**
# - Nigeria - nonsense calibration; finishes very late (April 2022) **DONE**
# - Honduras - modeLrate quality calibration **DONE** (perhaps resolved by some of the other changes)
# - Kenya - cross immunity parameter present **DONE**
# - Zambia - nonsense calibration due to very high early spike **DONE** (resolved by ignoring seroprevalence)
# - Lots of countries - seeding process not working well - need to seed per capita **DONE**
# - New issue - whether to include Delta for countries such as Pakistan
