# %% [raw]
# ---
# title: "Outputs"
# format:
#   pdf
# execute:
#   echo: false
#   warning: false
# jupyter: python3
# ---

# %%
from matplotlib_inline.backend_inline import set_matplotlib_formats
from matplotlib.pyplot import cm
from os import listdir as ls

from emu_renewal.inputs import OUTPUTS_PATH
from emu_renewal.outputs import get_country_procs
from emu_renewal.plotting import plot_proc_comparison

# %%
set_matplotlib_formats("svg")
colours = cm.Dark2.colors

# %%
job_path = OUTPUTS_PATH / "42780561"
countries = ls(job_path)

# %%
#| fig-cap: "Comparison of variable process by candidate mobility modifier."
procs = get_country_procs(job_path, countries)
plot_proc_comparison(procs, countries, colours, "Variable process comparison", job_path)
