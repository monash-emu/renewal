# %%
from emu_renewal.outputs import get_output_dir, get_mutlianalysis_ind_spaghetti, plot_process_comparison

# %%
country = "Spain"
analysis_times = {
    "no_mob": "20250116_1321",
    "google_nonresi_linear": "20250116_1335",
    "google_nonresi_square": "20250116_1344",
}

# %%
spagh_df = get_mutlianalysis_ind_spaghetti(country, "process", analysis_times)

# %%
plot_process_comparison(spagh_df, analysis_times.keys(), ["k", "cornflowerblue", "mediumblue"], 0.2)
