# %% [raw]
# ---
# title: "Comparisons of variable process profile under each mobility configuration"
# format:
#   pdf:
#     toc: true
# execute:
#   echo: false
#   warning: false
# jupyter: python3
# ---

# %%
from matplotlib_inline.backend_inline import set_matplotlib_formats
from matplotlib.pyplot import cm
from os import listdir as ls
from IPython.display import display, Markdown
import pycountry_convert as pc

from emu_renewal.constants import OUTPUTS_PATH
from emu_renewal.outputs import get_country_procs
from emu_renewal.plotting import plot_proc_comparison
from emu_renewal.utils import get_countries_by_continent, split_list_into_segments

set_matplotlib_formats("svg")

# %%
job_path = OUTPUTS_PATH / "46090067"
all_countries = ls(job_path)
countries_by_cont = get_countries_by_continent(all_countries)
procs = get_country_procs(job_path, all_countries)

# %% [markdown]
# # Purpose
# This document presents comparisons of the variable process
# across each mobility analysis approach for each country,
# along with the 90% credible interval associated with each.
# We would expect that approaches to analysis that
# if applying mobility captured some part of the variation
# in transmission that would otherwise need to be
# included through variation in the variable process,
# then that mobility approach would be associated with
# less dramatic changes in the variable process.
#
# # Results by continent

# %%
for cont in countries_by_cont:
    cont_name = pc.convert_continent_code_to_continent_name(cont)
    display(Markdown(f"## {cont_name}"))
    cont_countries = countries_by_cont[cont]
    for cs in split_list_into_segments(cont_countries, 9):
        display(plot_proc_comparison(procs, cs, cont_name, job_path, 3))
