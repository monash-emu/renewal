# %%
from emu_renewal.constants import OUTPUTS_PATH
from emu_renewal.plotting import get_standard_subplot, plot_mob_weights_by_country

# %%
job_path = OUTPUTS_PATH / "47213985"

# %%
countries = ["AUT", "DEU", "FRA", "GBR", "CAN", "USA", "ISR", "TUR", "KOR", "IRL", "CMR"]
fig = plot_mob_weights_by_country(job_path, countries)

# %%
fig.savefig("figure_3.svg")
