# %%
from matplotlib_inline.backend_inline import set_matplotlib_formats
from os import listdir as ls

from emu_renewal.constants import OUTPUTS_PATH
from emu_renewal.plotting import plot_mob_exp_analysis

set_matplotlib_formats("svg")

# %%
job_path = OUTPUTS_PATH / "46090067"
countries = ls(job_path)

# %%
fig = plot_mob_exp_analysis(job_path)

# %%
fig.savefig("figure_3.png", dpi=300)
