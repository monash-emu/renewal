# %%
from emu_renewal.utils import get_analysis_status

# %%
run_id = "50038825"

# %%
status = get_analysis_status(run_id)

# %%
status["fb_singletile_mob"].value_counts()

# %%
status[(status["fb_singletile_mob"] == "no log") | (status["fb_singletile_mob"] == "not run")]
