# %%
import json
from datetime import datetime
import pycountry

from emu_renewal.constants import DATA_PATH, ANALYSIS_TYPES, DATE_FORMAT
from emu_renewal.run import run_single_country

# %%
countries = json.load(open(DATA_PATH / f"config/included.json", "r"))
country = pycountry.countries.lookup("Switzerland")
country
# Out:
# Country(alpha_2='CH', alpha_3='CHE', flag='🇨🇭', name='Switzerland', numeric='756', official_name='Swiss Confederation')

# %%
analysis_time = datetime.now().strftime(DATE_FORMAT)
for country in [country.alpha_3]:
    for mob_analysis_type in ["no_mob"]:
        run_single_country(country, mob_analysis_type, analysis_time, prog_bar=True)
# Out:
# C:\Users\jtrauer\dev\renewal\code\emu_renewal\calibration.py:95: UserWarning: Model dates exclude all data for target seropos, disabling target
#   warn(f"Model dates exclude all data for target {ind}, disabling target")
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]
