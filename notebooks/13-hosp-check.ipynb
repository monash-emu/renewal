# %%
from datetime import datetime
import pycountry
from emu_renewal.inputs import get_hosp_target

# %%
country = "Switzerland"
iso3 = pycountry.countries.lookup(country).alpha_3
hosp_indicator = "Weekly new hospital admissions"
# hosp_indicator = "Daily hospital occupancy"
target = get_hosp_target(iso3, datetime(2020, 1, 1), datetime(2021, 12, 31), hosp_indicator)

# %%
target.plot()
